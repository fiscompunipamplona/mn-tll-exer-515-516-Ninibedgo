# %%
from google.colab import drive
drive.mount('/content/gdrive/')
import sys
sys.path.append('/content/gdrive/My Drive/ejecicioclase 5,16')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
import numpy
import math

print('librerias')
# Out:
# librerias

# %%
Errora=2                 # se definen las variables
Errorc=1
h=0
c=1e-16
                         # se realiza un bucle while
while Errora >= Errorc:  # se escribe la condicion
  h += 0.5               # variable de control
  Errora=(h/2)           # se define la ecuacion del error por el metodo hacia adelante
  Errorc=(h**2)/24       # se define la ecuacion del error por el metodo de centrales
  
  
  print('Error metodo adelante:',Errora)
  print('Error metodo central:',Errorc)
  print('valor de h:',h)
# Out:
# Error metodo adelante: 0.25
# Error metodo central: 0.010416666666666666
# valor de h: 0.5
# Error metodo adelante: 0.5
# Error metodo central: 0.041666666666666664
# valor de h: 1.0
# Error metodo adelante: 0.75
# Error metodo central: 0.09375
# valor de h: 1.5
# Error metodo adelante: 1.0
# Error metodo central: 0.16666666666666666
# valor de h: 2.0
# Error metodo adelante: 1.25
# Error metodo central: 0.2604166666666667
# valor de h: 2.5
# Error metodo adelante: 1.5
# Error metodo central: 0.375
# valor de h: 3.0
# Error metodo adelante: 1.75
# Error metodo central: 0.5104166666666666
# valor de h: 3.5
# Error metodo adelante: 2.0
# Error metodo central: 0.6666666666666666
# valor de h: 4.0
# Error metodo adelante: 2.25
# Error metodo central: 0.84375
# valor de h: 4.5
# Error metodo adelante: 2.5
# Error metodo central: 1.0416666666666667
# valor de h: 5.0
# Error metodo adelante: 2.75
# Error metodo central: 1.2604166666666667
# valor de h: 5.5
# Error metodo adelante: 3.0
# ...
